# %% [markdown]
# # 07 - Package & Release
#
# Package the best model (Model C) for public release:
# 1. Export to HuggingFace format
# 2. Create inference CLI
# 3. Upload to HuggingFace Hub
# 4. Archive datasets to Zenodo
# 5. Generate model card
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kluless/marinemamba/blob/main/notebooks/07_release.ipynb)

# %%
# TODO: Package best model
#
# 1. Save model weights in HuggingFace format
# 2. Create model card (README.md for HF repo)
# 3. Push to huggingface.co/kluless/marinemamba
# 4. Create Zenodo deposit for datasets
# 5. Create simple inference script:
#
#    from marinemamba import MarineMamba
#    model = MarineMamba.from_pretrained("kluless/marinemamba")
#    predictions = model.classify("path/to/sequences.fasta")

print("TODO: Implement release pipeline")

# %% [markdown]
# ## Done!
#
# At this point you should have:
# - Published model on HuggingFace
# - Archived datasets on Zenodo (with DOI)
# - Complete GitHub repo with notebooks and code
# - All figures ready for the paper
#
# Target journals: SoftwareX, Molecular Ecology Resources, Methods in Ecology and Evolution
