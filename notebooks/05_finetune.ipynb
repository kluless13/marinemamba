# %% [markdown]
# # 05 - Fine-tune & Evaluate
#
# Fine-tune all model variants and run full evaluation:
# - Species accuracy (seen species, test split)
# - Genus accuracy (unseen genera, kNN probe)
# - Linear probing
# - Data efficiency curves
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kluless/marinemamba/blob/main/notebooks/05_finetune.ipynb)

# %%
# === COLAB SETUP (same as 04) ===
# See notebook 04 for full install commands

# %%
# TODO: For each model (A, B, C, D):
#
# 1. Fine-tune with classification head
#    python train.py \
#      dataset=marine_fish_finetune \
#      dataset.input_path=../data/processed/ \
#      model.n_classes=<N_SPECIES> \
#      tokenizer=k_mer \
#      train.pretrained_model_path=<checkpoint>
#
# 2. Linear probing
#    python linear_probing.py \
#      --checkpoint <checkpoint> \
#      --data_dir ../data/processed/
#
# 3. kNN probing on unseen genera
#    python knn_probing.py \
#      --checkpoint <checkpoint> \
#      --train_file supervised_train.csv \
#      --test_file unseen.csv \
#      --label_col genus_name

print("TODO: Implement fine-tuning loop for all 4 models")
print("See BarcodeMamba repo for train.py, linear_probing.py, knn_probing.py")

# %%
# TODO: Data efficiency experiment
# For Model C only, repeat fine-tuning with subsets of training data:
# - 10% of training data
# - 25%
# - 50%
# - 100%
#
# Record species accuracy at each level
# This shows how much labeled data is needed — important for practical eDNA use

print("TODO: Data efficiency curves")

# %%
# Save all results
# results = {
#     "model_a_transfer": {...},
#     "model_b_scratch": {...},
#     "model_c_adapted": {...},
#     "model_d_supervised": {...},
#     "data_efficiency": {...}
# }
# json.dump(results, open("../results/model_comparison.json", "w"), indent=2)

print("TODO: Save comparison results")

# %% [markdown]
# ## Next
#
# Proceed to `06_analysis.ipynb` for figures and deep analysis.
