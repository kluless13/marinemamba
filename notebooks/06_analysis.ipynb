# %% [markdown]
# # 06 - Analysis & Figures
#
# Generate all paper figures and analysis:
# 1. Head-to-head comparison table
# 2. Per-family accuracy heatmap
# 3. UMAP of learned embeddings
# 4. Data efficiency learning curves
# 5. Failure analysis
# 6. Speed benchmark
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kluless13/marinemamba/blob/main/notebooks/06_analysis.ipynb)

# %%
# !pip install matplotlib seaborn umap-learn pandas

import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

plt.style.use('seaborn-v0_8-paper')
plt.rcParams['figure.dpi'] = 150

RESULTS_DIR = Path("../results")
FIG_DIR = Path("../results/figures")
FIG_DIR.mkdir(parents=True, exist_ok=True)

# %%
# TODO: Load results from notebooks 03 and 05
# baselines = json.load(open(RESULTS_DIR / "baselines.json"))
# models = json.load(open(RESULTS_DIR / "model_comparison.json"))

print("TODO: Load and visualize results")
print("\nFigures to generate:")
print("  Fig 1: Model comparison bar chart (species acc, genus acc, speed)")
print("  Fig 2: Per-family accuracy heatmap for Model C")
print("  Fig 3: UMAP of embeddings colored by order/family")
print("  Fig 4: Data efficiency learning curves")
print("  Fig 5: Confusion matrix (genus level)")
print("  Fig 6: Transfer analysis — insect vs fish embedding shift")

# %% [markdown]
# ## Next
#
# Proceed to `07_release.ipynb` to package the model for release.
